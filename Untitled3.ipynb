# %% [markdown]
# <a href="https://colab.research.google.com/github/25tec2csib038-dot/data-analytics/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
review = "The product quality was excellent, but delivery was delayed by two days."
words = review.split()
print("Word count:", len(words))
print("Contains 'delayed':", "delayed" in review)
# Out:
# Word count: 12
# Contains 'delayed': True
