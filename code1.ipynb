# %% [markdown]
# <a href="https://colab.research.google.com/github/25tec2csib038-dot/data-analytics/blob/main/code1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
student = {"Name": "", "Age": 21, "Marks": 85}
print(student)
print(type(student))
# Out:
# {'Name': 'Kishan', 'Age': 21, 'Marks': 85}
# <class 'dict'>

# %%
college = {"kishan": "ABC Institute",
"departments": [{"name": "CSE", "students": 120},
{"name": "ECE", "students": 90}]}
print(college["departments"][0]["name"])
# Out:
# CSE

# %%
review = "The product quality was excellent, but delivery was delayed by two days."
words = review.split()
print("Word count:", len(words))
print("Contains 'delayed':", "delayed" in review)
# Out:
# Word count: 12
# Contains 'delayed': True

# %%
samples = [
    {"type": "structured", "value": {"Name": "Raj", "Age": 20}},
    {"type": "semi-structured", "value": {"tags": ["python", "data"]}},
    {"type": "unstructured", "value": "A long free-text customer comment..."}
]

for s in samples:
    print(f"{s['type']}: {type(s['value']).__name__}")
# Out:
# structured: dict
# semi-structured: dict
# unstructured: str
