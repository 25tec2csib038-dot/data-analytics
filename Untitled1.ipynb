# %% [markdown]
# <a href="https://colab.research.google.com/github/25tec2csib038-dot/data-analytics/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
college = {"name": "ABC Institute",
"departments": [{"name": "CSE", "students": 120},
{"name": "ECE", "students": 90}]}
print(college["departments"][0]["name"])
# Out:
# CSE
