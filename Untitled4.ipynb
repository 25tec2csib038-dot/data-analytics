# %% [markdown]
# <a href="https://colab.research.google.com/github/25tec2csib038-dot/data-analytics/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
samples = [
    {"type": "structured", "value": {"Name": "Raj", "Age": 20}},
    {"type": "semi-structured", "value": {"tags": ["python", "data"]}},
    {"type": "unstructured", "value": "A long free-text customer comment..."},
]

for s in samples:
    print(f"{s['type']}: {type(s['value']).__name__}")
# Out:
# structured: dict
# semi-structured: dict
# unstructured: str
