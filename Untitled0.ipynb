# %% [markdown]
# <a href="https://colab.research.google.com/github/25tec2csib038-dot/data-analytics/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
student = {"Name": "Amit", "Age": 21, "Marks": 85}
print(student)
print(type(student))
# Out:
# {'Name': 'Amit', 'Age': 21, 'Marks': 85}
# <class 'dict'>
